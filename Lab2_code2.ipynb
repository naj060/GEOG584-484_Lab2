# %%
from matplotlib import pyplot as plt

y= [34, 56, 56, 67, 89, 45, 67, 43]
vb = ['Jan', 'Feb','Mar', 'April', 'May', 'June', 'July', 'Aug']
x1 = [1,2,3,4,5,6,7,8]
   
width = 0.75 
    
plt.bar(x1, y, width, facecolor='blue')
plt.xticks(x1, vb, rotation='30')
plt.xlabel("Individual Cases")
plt.ylabel("Thousands")
plt.title("Value")
plt.show()
